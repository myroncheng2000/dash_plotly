# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_excel('covid-19.xlsx')
df.tail(15)
# Out:
#         country country_code continent  population indicator  weekly_count  \
# 20637  Zimbabwe          ZWE    Africa    14862927    deaths             2
# 20638  Zimbabwe          ZWE    Africa    14862927    deaths             1
# 20639  Zimbabwe          ZWE    Africa    14862927    deaths             6
# 20640  Zimbabwe          ZWE    Africa    14862927    deaths             6
# 20641  Zimbabwe          ZWE    Africa    14862927    deaths            10
# 20642  Zimbabwe          ZWE    Africa    14862927    deaths             4
# 20643  Zimbabwe          ZWE    Africa    14862927    deaths            11
# 20644  Zimbabwe          ZWE    Africa    14862927    deaths             8
# 20645  Zimbabwe          ZWE    Africa    14862927    deaths            15
# 20646  Zimbabwe          ZWE    Africa    14862927    deaths            16
# 20647  Zimbabwe          ZWE    Africa    14862927    deaths            13
# ...

# %%
import numpy as np
dff = pd.pivot_table(df,index=['country'], columns=['indicator'], values=['weekly_count'], 
                     aggfunc=[np.sum], fill_value=0)['sum']['weekly_count']
#dff = dff[~dff['country'].str.contains('total')]
dff.reset_index()
dff.index
# Out:
# Index(['Afghanistan', 'Africa (total)', 'Albania', 'Algeria',
#        'America (total)', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda', 'Argentina',
#        ...
#        'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam', 'Wallis and Futuna',
#        'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe',
#        'the Holy See/ Vatican City State'],
#       dtype='object', name='country', length=220)

# %%
import pandas_datareader.data as web
import datetime
start = datetime.datetime.now() - datetime.timedelta(days=365) #datetime.datetime(2020, 1, 1)
end = datetime.datetime.now() #datetime.date.today() #datetime.datetime(2020, 12, 3)
df = web.DataReader(['AMZN','GOOGL','FB','PFE','MRNA','BNTX'],
                    'stooq', start=start, end=end)
print(start)
print(end)
# Out:
# 2020-02-08 10:39:59.961612
# 2021-02-07 10:39:59.962630

# %%
#df = df.stack().reset_index()
df.tail()
# Out:
# Attributes       Date Symbols     Close      High        Low      Open  \
# 1501       2020-02-10   GOOGL  1508.660  1508.880  1475.2000  1477.230
# 1502       2020-02-10      FB   213.060   213.800   210.6600   211.520
# 1503       2020-02-10     PFE    36.698    37.096    36.6100    37.086
# 1504       2020-02-10    MRNA    23.650    23.950    22.3832    23.500
# 1505       2020-02-10    BNTX    32.120    32.150    30.1100    30.990
#
# Attributes    Volume
# 1501         1915072
# 1502        11856350
# 1503        19549201
# 1504         9356771
# 1505          121714

# %%
import datetime
start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2020, 12, 3)
print(type(start))
print(end)
# Out:
# <class 'datetime.datetime'>
# 2020-12-03 00:00:00

# %%
datetime.date.today()
# Out:
# datetime.date(2021, 2, 7)
